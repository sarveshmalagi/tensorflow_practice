# %%
import tensorflow as tf

# %%
sess = tf.InteractiveSession()

# %%
my_tens = tf.random_uniform((4,4), 0, 1)

# %%
my_tens
# Out:
# <tf.Tensor 'random_uniform:0' shape=(4, 4) dtype=float32>

# %%
my_var = tf.Variable(initial_value=my_tens)

# %%
print(my_var)
# Out:
# <tf.Variable 'Variable:0' shape=(4, 4) dtype=float32_ref>

# %%
init = tf.global_variables_initializer()

# %%
sess.run(init)

# %%
sess.run(my_var)
# Out:
# array([[0.27084863, 0.4484489 , 0.73508596, 0.4381653 ],
#        [0.44352674, 0.7796093 , 0.95933616, 0.3647287 ],
#        [0.40154433, 0.8626151 , 0.98707604, 0.41430485],
#        [0.01334798, 0.4305842 , 0.34285545, 0.42902613]], dtype=float32)

# %%
ph = tf.placeholder(tf.float32, (None, 5))
